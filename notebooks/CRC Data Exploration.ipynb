# %%
import pandas as pd

# %%
Tou = pd.read_csv('../raw_data/df_A_avg_ToU_v1.csv')

# %%
Tou.head()
# Out:
#    Unnamed: 0             DateTime  KWH/hh tariff
# 0           0  2012-01-01 00:00:00   0.279    ToU
# 1           1  2012-01-01 00:30:00   0.296    ToU
# 2           2  2012-01-01 01:00:00   0.350    ToU
# 3           3  2012-01-01 01:30:00   0.286    ToU
# 4           4  2012-01-01 02:00:00   0.254    ToU

# %%
summary = pd.read_csv('../raw_data/summary_v1.csv')

# %%
summary[(summary['Acorn'] == 'ACORN-A') & (summary['tariff'] == 'ToU')]
# Out:
#      Unnamed: 0      LCLid           start_date             end_date  \
# 105         105  MAC000339  2012-03-08 10:00:00  2014-02-28 00:00:00
# 106         106  MAC000464  2012-03-23 10:00:00  2014-02-28 00:00:00
# 107         107  MAC000487  2012-03-23 16:00:00  2014-02-28 00:00:00
# 108         108  MAC000593  2012-04-12 09:30:00  2014-02-28 00:00:00
# 109         109  MAC000609  2012-04-12 11:30:00  2014-02-28 00:00:00
# 110         110  MAC000797  2012-04-25 09:30:00  2014-02-04 00:00:00
# 111         111  MAC001653  2013-10-24 00:30:00  2014-02-28 00:00:00
# 112         112  MAC001736  2012-06-01 13:00:00  2013-12-09 23:30:00
# 115         115  MAC002113  2012-06-18 08:30:00  2014-02-28 00:00:00
# 116         116  MAC002134  2012-06-18 12:30:00  2014-02-28 00:00:00
# 117         117  MAC002199  2012-06-25 08:30:00  2014-02-28 00:00:00
# 119         119  MAC002552  2012-07-09 12:00:00  2014-02-28 00:00:00
# 120         120  MAC002959  2012-07-05 00:30:00  2014-02-28 00:00:00
# ...
